# %%
# Import modules
import pandas as pd
import numpy as np
import os
from pathlib import Path

# %%
# Set and check data path
data_path = r"/content/drive/MyDrive/Projektek/Semmelweis PoC/202401_Semmelweis - GenAI anamnézis - PoC (425)/10_Kapott_anyagok/kapott_anyagok_ 2024_02_06"
os.listdir(data_path)
# Out:
# ['zarok_ai_utolso_szoveg_verzio_20240204.xlsx',
#  '.ipynb_checkpoints',
#  'patient']

# %%
# Select input file from data path
filename = 'zarok_ai_utolso_szoveg_verzio_20240204.xlsx'

# Set file path
file_path = os.path.join(data_path, filename)
print(file_path)

# fname_base = Path(file_path).stem
# print(fname_base)
# Out:
# /content/drive/MyDrive/Projektek/Semmelweis PoC/202401_Semmelweis - GenAI anamnézis - PoC (425)/10_Kapott_anyagok/kapott_anyagok_ 2024_02_06/zarok_ai_utolso_szoveg_verzio_20240204.xlsx

# %%
# Read raw file into pandas dataframe
df_raw = pd.read_excel(file_path, dtype={'NPI':'object', 'CASE_NO':'object'}).convert_dtypes()

# Correct column types and names
df_raw['ADMIT_DATE'] = df_raw['ADMIT_DATE'].dt.date

df_raw = df_raw.rename(columns={
    'Ananmézis': 'Anamnézis',
    # 'Jelen panaszok': 'Jelenlegi panaszok',
    # 'Dekurzus': 'Dekurzus',
    # 'Epikrízis': 'Epikrízis',
    # 'Egyéb vizsgálatok': 'Egyéb vizsgálatok',
    # 'Műtéti leírás': 'Műtéti leírás',
    # 'Státusz': 'Státusz',
    # 'Javaslat': 'Javaslat',
    'Therápia': 'Terápia'
})

df_raw.info()
df_raw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3469 entries, 0 to 3468
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NPI                3469 non-null   string
#  1   CASE_NO            3469 non-null   Int64
#  2   ADMIT_DATE         3469 non-null   object
#  3   CASE_TYPE          3469 non-null   string
#  4   DEPT               3469 non-null   string
#  5   DESCR              3469 non-null   string
#  6   TX_TYPE            3469 non-null   string
#  7   VER_NO             3469 non-null   Int64
#  8   SEQ_NO             3469 non-null   Int64
#  9   Anamnézis          791 non-null    string
#  10  Jelen panaszok     529 non-null    string
#  11  Dekurzus           184 non-null    string
#  12  Epikrízis          1089 non-null   string
#  13  Egyéb vizsgálatok  100 non-null    string
#  14  Műtéti leírás      14 non-null     string
#  15  Státusz            611 non-null    string
#  16  Javaslat           47 non-null     string
#  17  Terápia            26 non-null     string
# dtypes: Int64(3), object(1), string(14)
# memory usage: 498.1+ KB
#             NPI   CASE_NO  ADMIT_DATE CASE_TYPE DEPT  \
# 0     008359041  13727918  2014-01-31         I   NE
# 1     008359041  13727918  2014-01-31         I   NE
# 2     008359041  13727918  2014-01-31         I   NE
# 3     008359041  13727918  2014-01-31         I   NE
# 4     008359041  14456076  2014-08-02         I  B20
# ...         ...       ...         ...       ...  ...
# 3464  128082786  31642742  2024-01-17         O  G1P
# 3465  128082786  31642742  2024-01-17         O  G1P
# 3466  128082786  31710528  2024-01-30         O  G1P
# 3467  128082786  31710528  2024-01-30         O  G1P
# 3468  128082786  31710528  2024-01-30         O  G1P
#
#                                 DESCR TX_TYPE  VER_NO  SEQ_NO  \
# 0      Általános Neurológia és stroke     ANM       1       0
# 1      Általános Neurológia és stroke     CPL       2       0
# 2      Általános Neurológia és stroke     dec       6       0
# 3      Általános Neurológia és stroke     STA       1       0
# 4                            Intenzív     ANM       6       0
# ...                               ...     ...     ...     ...
# 3464  Gyermekpszichiátriai Ambulancia     DEC       1       0
# 3465  Gyermekpszichiátriai Ambulancia     STA       1       0
# 3466  Gyermekpszichiátriai Ambulancia     ANM       1       0
# 3467  Gyermekpszichiátriai Ambulancia     EPD       3       0
# 3468  Gyermekpszichiátriai Ambulancia     STA       1       0
#
#                                               Anamnézis  \
# 0     Orvosi dok. nincs nála.
# 1980ban jobb o-i hydr...
# 1                                                  <NA>
# 2                                                  <NA>
# 3                                                  <NA>
# 4     1980-ban jobb o-i hydronephrosis miatt nephrec...
# ...                                                 ...
# 3464                                               <NA>
# 3465                                               <NA>
# 3466  A 15 éves, 9. osztályos serdülő édesanyjával é...
# 3467                                               <NA>
# 3468                                               <NA>
#
#                                          Jelen panaszok  \
# 0                                                  <NA>
# 1     A bal karját nem tudta emelni, nem érezte- ez ...
# 2                                                  <NA>
# 3                                                  <NA>
# 4                                                  <NA>
# ...                                                 ...
# 3464                                               <NA>
# 3465                                               <NA>
# 3466                                               <NA>
# 3467                                               <NA>
# 3468                                               <NA>
#
#                                                Dekurzus  \
# 0                                                  <NA>
# 1                                                  <NA>
# 2     01.31 felv. jobb acm ter. gyorsan enyhülő, csa...
# 3                                                  <NA>
# 4                                                  <NA>
# ...                                                 ...
# 3464  A gyermekpszichológiai konzílium eredménye ala...
# 3465                                               <NA>
# 3466                                               <NA>
# 3467                                               <NA>
# 3468                                               <NA>
#
#                                               Epikrízis Egyéb vizsgálatok  \
# 0                                                  <NA>              <NA>
# 1                                                  <NA>              <NA>
# 2                                                  <NA>              <NA>
# 3                                                  <NA>              <NA>
# 4                                                  <NA>              <NA>
# ...                                                 ...               ...
# 3464                                               <NA>              <NA>
# 3465                                               <NA>              <NA>
# 3466                                               <NA>              <NA>
# 3467  A 15 éves serdülő édesanyja kíséretében érkezi...              <NA>
# 3468                                               <NA>              <NA>
#
#      Műtéti leírás                                            Státusz  \
# 0             <NA>                                               <NA>
# 1             <NA>                                               <NA>
# 2             <NA>                                               <NA>
# 3             <NA>  Vérnyomás: jobb kar: 155/80 Hgmm,  Pulzus: 82/...
# 4             <NA>                                               <NA>
# ...            ...                                                ...
# 3464          <NA>                                               <NA>
# 3465          <NA>  Tudata éber, integrált, minden tekintetben ori...
# 3466          <NA>                                               <NA>
# 3467          <NA>                                               <NA>
# 3468          <NA>  Tudata éber, integrált, minden tekintetben ori...
#
#      Javaslat Terápia
# 0        <NA>    <NA>
# 1        <NA>    <NA>
# 2        <NA>    <NA>
# 3        <NA>    <NA>
# 4        <NA>    <NA>
# ...       ...     ...
# 3464     <NA>    <NA>
# 3465     <NA>    <NA>
# 3466     <NA>    <NA>
# 3467     <NA>    <NA>
# 3468     <NA>    <NA>
#
# [3469 rows x 18 columns]

# %%
# Unpivot (melt) raw dataframe and drop empty rows
df_melt = df_raw.melt(
      id_vars=['NPI', 'CASE_NO', 'ADMIT_DATE', 'CASE_TYPE', 'DEPT', 'DESCR', 'TX_TYPE', 'VER_NO', 'SEQ_NO'],
      value_vars=['Anamnézis', 'Jelen panaszok', 'Dekurzus', 'Epikrízis', 'Egyéb vizsgálatok', 'Műtéti leírás', 'Státusz', 'Javaslat', 'Terápia'],
      var_name='TYPE',
      value_name='VALUE'
      ).dropna(subset='VALUE')

# Add specific sorting column
df_melt.insert(
    df_melt.columns.get_loc('TYPE'),
    'TYPE_ORDER',
    df_melt['TYPE'].replace(
        {
            'Anamnézis': 1,
            'Jelen panaszok': 2,
            'Dekurzus': 3,
            'Epikrízis': 4,
            'Egyéb vizsgálatok': 5,
            'Műtéti leírás': 6,
            'Státusz': 7,
            'Javaslat': 8,
            'Terápia': 9
    }
  ).convert_dtypes()
)

# Replace multiple whitespace characters in VALUE column
df_melt['VALUE'] = df_melt['VALUE'].str.replace(r' +', ' ', regex=True)
df_melt['VALUE'] = df_melt['VALUE'].str.replace(r'[\n\t\r\f]+', '\n', regex=True)

# Strip VALUE (and interpret empty string '' as NA)
df_melt['VALUE'] = df_melt['VALUE'].str.strip().replace('', pd.NA)

#
df_melt['TX_TYPE'] = df_melt['TX_TYPE'].str.upper()

# Add TYPE to TEXT
df_melt['TEXT'] = df_melt['TYPE'].str.upper() + ':\n' + df_melt['VALUE'].str.replace('\n', '\n\t')

# TEXT2
df_melt['TEXT2'] = df_melt['TYPE'].str.upper() + ' (' + df_melt['ADMIT_DATE'].astype(str) + '):\n' + df_melt['VALUE'].str.replace('\n', '\n\t')

# Drop NA, convert dtypes, and sort melt dataframe
df_melt = df_melt.dropna().convert_dtypes().sort_values(['NPI', 'ADMIT_DATE', 'CASE_NO', 'TYPE_ORDER'], ignore_index=True)
df_melt
# Out:
#             NPI   CASE_NO  ADMIT_DATE CASE_TYPE  DEPT  \
# 0     008359041  25054122  2010-03-30         O  SRN4
# 1     008359041  25369254  2010-04-21         O  KEUH
# 2     008359041  25476751  2010-04-21         O  BETJ
# 3     008359041  25066396  2010-04-23         O  SRN4
# 4     008359041  25481334  2010-05-14         O  SRRO
# ...         ...       ...         ...       ...   ...
# 3368  128082786  31642742  2024-01-17         O   G1P
# 3369  128082786  31642742  2024-01-17         O   G1P
# 3370  128082786  31710528  2024-01-30         O   G1P
# 3371  128082786  31710528  2024-01-30         O   G1P
# 3372  128082786  31710528  2024-01-30         O   G1P
#
#                                 DESCR TX_TYPE  VER_NO  SEQ_NO  TYPE_ORDER  \
# 0                  Neurológiai szakr.     ANM       1       0           1
# 1                           UH /hasi/     ANM       1       0           1
# 2            Betöltéshez járó osztály     ANM       1       0           1
# 3                  Neurológiai szakr.     ANM       1       0           1
# 4                 Ált.reumatol.szakr.     ANM       1       0           1
# ...                               ...     ...     ...     ...         ...
# 3368  Gyermekpszichiátriai Ambulancia     DEC       1       0           3
# 3369  Gyermekpszichiátriai Ambulancia     STA       1       0           7
# 3370  Gyermekpszichiátriai Ambulancia     ANM       1       0           1
# 3371  Gyermekpszichiátriai Ambulancia     EPD       3       0           4
# 3372  Gyermekpszichiátriai Ambulancia     STA       1       0           7
#
#            TYPE                                              VALUE  \
# 0     Anamnézis  Jo-i hydronephrosis miatt veseeltáv., ulcusbet...
# 1     Anamnézis  Rad.lelet
# KOPONYA CT VIZSGÁLAT
# A vizsgálat sor...
# 2     Anamnézis  Rad.lelet
# KOPONYA CT VIZSGÁLAT
# A vizsgálat sor...
# 3     Anamnézis  Kontroll vizsgálat:
# 10.04.21 Radiológia: , 2 ...
# 4     Anamnézis  Rad.lelet
# 2 ir. lumbalis gerinc felvétel:
# ----...
# ...         ...                                                ...
# 3368   Dekurzus  A gyermekpszichológiai konzílium eredménye ala...
# 3369    Státusz  Tudata éber, integrált, minden tekintetben ori...
# 3370  Anamnézis  A 15 éves, 9. osztályos serdülő édesanyjával é...
# 3371  Epikrízis  A 15 éves serdülő édesanyja kíséretében érkezi...
# 3372    Státusz  Tudata éber, integrált, minden tekintetben ori...
#
#                                                    TEXT  \
# 0     ANAMNÉZIS:
# Jo-i hydronephrosis miatt veseeltáv...
# 1     ANAMNÉZIS:
# Rad.lelet
# 	KOPONYA CT VIZSGÁLAT
# 	A ...
# 2     ANAMNÉZIS:
# Rad.lelet
# 	KOPONYA CT VIZSGÁLAT
# 	A ...
# 3     ANAMNÉZIS:
# Kontroll vizsgálat:
# 	10.04.21 Radi...
# 4     ANAMNÉZIS:
# Rad.lelet
# 	2 ir. lumbalis gerinc fe...
# ...                                                 ...
# 3368  DEKURZUS:
# A gyermekpszichológiai konzílium ere...
# 3369  STÁTUSZ:
# Tudata éber, integrált, minden tekint...
# 3370  ANAMNÉZIS:
# A 15 éves, 9. osztályos serdülő éde...
# 3371  EPIKRÍZIS:
# A 15 éves serdülő édesanyja kíséret...
# 3372  STÁTUSZ:
# Tudata éber, integrált, minden tekint...
#
#                                                   TEXT2
# 0     ANAMNÉZIS (2010-03-30):
# Jo-i hydronephrosis mi...
# 1     ANAMNÉZIS (2010-04-21):
# Rad.lelet
# 	KOPONYA CT ...
# 2     ANAMNÉZIS (2010-04-21):
# Rad.lelet
# 	KOPONYA CT ...
# 3     ANAMNÉZIS (2010-04-23):
# Kontroll vizsgálat:
# 	...
# 4     ANAMNÉZIS (2010-05-14):
# Rad.lelet
# 	2 ir. lumba...
# ...                                                 ...
# 3368  DEKURZUS (2024-01-17):
# A gyermekpszichológiai ...
# 3369  STÁTUSZ (2024-01-17):
# Tudata éber, integrált, ...
# 3370  ANAMNÉZIS (2024-01-30):
# A 15 éves, 9. osztályo...
# 3371  EPIKRÍZIS (2024-01-30):
# A 15 éves serdülő édes...
# 3372  STÁTUSZ (2024-01-30):
# Tudata éber, integrált, ...
#
# [3373 rows x 14 columns]

# %%
# Merge text
df_merged = df_melt.groupby(['NPI','ADMIT_DATE','CASE_NO','CASE_TYPE','DEPT','DESCR'])[['TEXT']].agg("\n\n".join).reset_index(level=-1)
df_merged
# Out:
#                                                                             DESCR  \
# NPI       ADMIT_DATE CASE_NO  CASE_TYPE DEPT
# 008359041 2010-03-30 25054122 O         SRN4                   Neurológiai szakr.
#           2010-04-21 25369254 O         KEUH                            UH /hasi/
#                      25476751 O         BETJ             Betöltéshez járó osztály
#           2010-04-23 25066396 O         SRN4                   Neurológiai szakr.
#           2010-05-14 25481334 O         SRRO                  Ált.reumatol.szakr.
# ...                                                                           ...
# 128082786 2023-01-19 29978989 O         FGA              Általános F.O.G. osztály
#           2023-02-10 29921771 O         FGT                         Otoneurológia
#           2024-01-09 31593207 I         G14   Belgyógyászat-Gastroenterológiai O.
#           2024-01-17 31642742 O         G1P       Gyermekpszichiátriai Ambulancia
#           2024-01-30 31710528 O         G1P       Gyermekpszichiátriai Ambulancia
#
#                                                                                            TEXT
# NPI       ADMIT_DATE CASE_NO  CASE_TYPE DEPT
# 008359041 2010-03-30 25054122 O         SRN4  ANAMNÉZIS:
# Jo-i hydronephrosis miatt veseeltáv...
#           2010-04-21 25369254 O         KEUH  ANAMNÉZIS:
# Rad.lelet
# 	KOPONYA CT VIZSGÁLAT
# 	A ...
#                      25476751 O         BETJ  ANAMNÉZIS:
# Rad.lelet
# 	KOPONYA CT VIZSGÁLAT
# 	A ...
#           2010-04-23 25066396 O         SRN4  ANAMNÉZIS:
# Kontroll vizsgálat:
# 	10.04.21 Radi...
#           2010-05-14 25481334 O         SRRO  ANAMNÉZIS:
# Rad.lelet
# 	2 ir. lumbalis gerinc fe...
# ...                                                                                         ...
# 128082786 2023-01-19 29978989 O         FGA   ANAMNÉZIS:
# 2023.01.19. Augusztus vége óta nem ...
#           2023-02-10 29921771 O         FGT   ANAMNÉZIS:
# 2022. augusztusban orrdugulásos pan...
#           2024-01-09 31593207 I         G14   ANAMNÉZIS:
# Negatív perinatalis anamnezis. III/...
#           2024-01-17 31642742 O         G1P   ANAMNÉZIS:
# Anamnéziséből kiemelendő: A 15 éves...
#           2024-01-30 31710528 O         G1P   ANAMNÉZIS:
# A 15 éves, 9. osztályos serdülő éde...
#
# [1705 rows x 2 columns]

# %%
df_anm_all = df_melt[df_melt['TX_TYPE'] == 'ANM'].groupby(['NPI'])[['VALUE']].agg("\n\n".join)
df_anm_all
# Out:
#                                                        VALUE
# NPI
# 008359041  Jo-i hydronephrosis miatt veseeltáv., ulcusbet...
# 011547185  EF 50% , RDA prox hosszú, meszes 40%-os sten, ...
# 013763925  A beteg anamnézisében hypertonia, parox. PF, C...
# 014317617  Kórelőzméynéből kiemelhető:
# hypertonia, 2tDM, ...
# 017366126  11 éve tonsilectomia kb. 1968-ban j.o. váll fi...
# 019116202  2009.10.26-án reggeli órákban tipusos tüneteke...
# 019131629  12 cm-nél szövettanilag igazolt tumor a végbél...
# 021009268  Előző betegségek:
# 2002 óta ismert DCM
# Inzulin...
# 021508668  Szívtranszplantáció céljából került felvételre...
# 022231615  A beteg elmondása és korábbi dokumentációja al...
# 022387169  A beteg releváns anamnézisében 2014. nyarán ve...
# 022461890  Előzmények: Achilles ín szakadás miatt opus. 2...
# 023283291  Távolabbi anamnézisében 20 éve ismert, gyógysz...
# 023774843  Ülő helyzetben jelentkező j.o. alsó végtagba s...
# 023799222  HTX-re érkezett 2015.07.04-én, OMSZ szállítja ...
# 024264958  2019.03. STEMI inferior miatt kezelés. CX PCI,...
# 027883336  HTN, hyperuricaemia, 2012-től gondozott idiopa...
# 028520047  Anamnézisében 2008-ban antereior STEMI, LAD PC...
# 029552184  A beteget szívtranszplantáció lehetséges recip...
# 042344593  Fiatal férfi betegtől anamnézis nem nyerhető.
# ...
# 058754654  Osztályra kerülés módja: előjegyzés (Dr. Falud...
# 062458289  Fejfájás miatt végzett MR vizsgálaton merült f...
# 064740335  Anamnesisében tonsillectomia, appendectomia, m...
# 069692954  sA beteg elmondása és korábbi dokumentációja a...
# 071261537  A beteg anamnézisében érdemi belszervi megbete...
# 074177352  bal fülében időszakosan fájdalmat érez.Időszak...
# 078391338  Hányadik terhesség: 5
# Hányadik szülés : 3
# Utol...
# 094385775  Távolabbi anamnézisében GERD, errosiv gastriti...
# 094754894  Évek óta gondozás Honvéd Kh. Kardiológia- szív...
# 102195156  EF , sten RDA, sten Cx, sten IM, sten CD, sten...
# 104787935  2002: ulcus duod.
# 2007: coro: neg
# 2011.08: CRT...
# 105368364  Anamnézisét illetően a 2004.08.23-i zárójelent...
# 128082786  3470g, III/III, családi anamnesis neg, fejvégű...

# %%
df_epd_all = df_melt[df_melt['TX_TYPE'] == 'EPD'].groupby(['NPI'])[['VALUE']].agg("\n\n".join)
df_epd_all
# Out:
#                                                        VALUE
# NPI
# 008359041  Dg.: Pneumonia (atípusos). Insuff cordis. (NYH...
# 011547185  A beteget CABG III (LIMA-LAD, VSG-OM, -IVP) mű...
# 013763925  A beteg kontrollvizsgálaton megjelent. NYHA II...
# 014317617  Varratszedés megtörtént, seb pp.gyógyult, béké...
# 017366126  Diagnózisok: Ischaemiás szívbetegség
#  St.p.inf...
# 019116202  Múlthét csütörtök óta belégzési nehezítettségg...
# 019131629  A beteget neo-adjuvans kezelés után, szövettan...
# 021009268  szivelégtelenség gondozást kezdtünk
# SG vgolt, ...
# 021508668  Fent részletezett anamnézisű beteg szívtranszp...
# 022231615  Fenti anamnézisű beteg 2015.04.03-án ortotopik...
# 022387169  A beteget szívelégtelenség miatt vizsgáljuk.
# ...
# 022461890  AITK EPIKRÍZIS HELYE ..... :-)
#
# Fenti anamnéz...
# 023283291  Dg: Diabetes mellitus. Pancreatitis chronica. ...
# 023774843  Laborvizsgálatra vettünk vért.
# Koponya MR vizs...
# 023799222  Fenti anamnézisű beteg 2015.07.04-én ortotopik...
# 024264958  A beteget primer prevenciós ICD beültetésre ve...
# 027883336  A fenn részletezett anamnézisű beteget ortotop...
# 028520047  A betegnél 2008. májusban ant. inf.-ban LAD PC...
# 029552184  A beteget a Magyar HTX bizottság kérésére, spi...
# 042344593  A fenn részletezett anamnézisű beteget a műtőb...
# 058754654  Dg.: St.p.impl.valv.artef.mitr (1997 Sorin Bic...
# 062458289  Sinusitis pontos megitélése végett célzott arc...
# 064740335  Hypertonia, mellkasi dyscomfortérzet miatt álo...
# 069692954  A 2001 óta idiopathiás dilatatív cardiomyopath...
# 071261537  A negatív anamnézisű 50 éves nőbeteg terhelésr...
# 074177352  2022.10.21 12:57 MP
# Jelen panaszok: HO irányít...
# 078391338  Hypertonia, thyreoiditis miatt kezelt betegünk...
# 094385775  A fenn részletezett anamnézisű beteget ortotop...
# 094754894  spiroergo: 13.3ml/kg/perc
# Fábry bet: vér: norm...
# 102195156  A fent részlezett anamnézisű beteget OPCAB III...
# 104787935  A beteget csökkent EF, tolerálható OMT melleti...
# 105368364  Diagnózis: Dilatativ cardiomyopathia.
#  Diab. m...
# 128082786  Fenti panaszok miatt vizsgáljuk. Fizikális stá...

# %%
# Write each patient document (per case number) to txt files
ext = 'txt'
dir = 'patient'
full_subdir = 'src/full'

for i in df_merged.index:
  # Get metadata
  npi = i[0]
  admit_date = i[1]
  case_no = i[2]
  case_type = i[3]
  dept = i[4]

  # Set patient folder as NPI
  patient_dir = f'{(i[0])}'
  output_dir = os.path.join(data_path, dir, patient_dir, full_subdir)

  # Make output directory if does not exist
  if not os.path.exists(output_dir):
      os.makedirs(output_dir)

  # Set output filename as NPI+ADMIT_DATE+CASE_NO+CASE_TYPE+DEPT
  fname = f'{npi}_{admit_date}_{case_no}_{case_type}_{dept}.{ext}'
  output_file = os.path.join(output_dir, fname)

  # Get content for output file
  department = df_merged.loc[i, 'DESCR']
  text = df_merged.loc[i, 'TEXT']

  # Create header
  header = f'ZÁRÓJELENTÉS\nPáciens: {npi} | Rögzítési dátum: {admit_date} | Dokumentum: {case_no} | Osztály: {department} ({dept})\n\n'

  # Write output file
  print(f'\rWriting case {case_no} for patient {npi}\t\t', end='')
  with open(output_file, 'w') as f:
    f.write(header)
    f.write(text)


# Write merged medical history for each patient
merged_subdir = 'src/merged'
for i in df_anm_all.index:
  # Get data
  npi = i
  text = df_anm_all.loc[i, 'VALUE']

  # Set patient folder as NPI
  patient_dir = f'{npi}'
  output_dir = os.path.join(data_path, dir, patient_dir, merged_subdir)

  # Make output directory if does not exist
  if not os.path.exists(output_dir):
      os.makedirs(output_dir)

  # Set output filename
  fname = f'{npi}_ANM_MERGED.{ext}'
  output_file = os.path.join(output_dir, fname)

  # Write output file
  print(f'\rWriting merged medical history (anamnesis) for patient {npi}\t\t', end='')
  with open(output_file, 'w') as f:
    f.write(text)


# Write merged epicrisis for each patient
merged_subdir = 'src/merged'
for i in df_epd_all.index:
  # Get data
  npi = i
  text = df_epd_all.loc[i, 'VALUE']

  # Set patient folder as NPI
  patient_dir = f'{npi}'
  output_dir = os.path.join(data_path, dir, patient_dir, merged_subdir)

  # Make output directory if does not exist
  if not os.path.exists(output_dir):
      os.makedirs(output_dir)

  # Set output filename
  fname = f'{npi}_EPD_MERGED.{ext}'
  output_file = os.path.join(output_dir, fname)

  # Write output file
  print(f'\rWriting merged epicrisis for patient {npi}\t\t', end='')
  with open(output_file, 'w') as f:
    f.write(text)

print('\rAll files complete')
# Out:
# All files complete

# %%
df_merged.reset_index().groupby("NPI")[['CASE_NO']].count()
# Out:
#            CASE_NO
# NPI
# 008359041       50
# 011547185       37
# 013763925       42
# 014317617       50
# 017366126      103
# 019116202       40
# 019131629       20
# 021009268       52
# 021508668       48
# 022231615       73
# 022387169       92
# 022461890       51
# 023283291       28
# 023774843       10
# 023799222       69
# 024264958       13
# 027883336       52
# 028520047      121
# 029552184       47
# 042344593       41
# 058754654        7
# 062458289       12
# 064740335       14
# 069692954       48
# 071261537      131
# 074177352       19
# 078391338       45
# 094385775       53
# 094754894       82
# 102195156       11
# 104787935       93
# 105368364      140
# 128082786       11

# %% [markdown]
# # Filtering for anamnesis and epicrisis only

# %%
df_melt['FINAL_TEXT'] = df_melt.apply(lambda row: row['TEXT'] if row['TX_TYPE'] == 'ANM' else row['TEXT2'], axis=1)
df_melt
# Out:
#             NPI   CASE_NO  ADMIT_DATE CASE_TYPE  DEPT  \
# 0     008359041  25054122  2010-03-30         O  SRN4
# 1     008359041  25369254  2010-04-21         O  KEUH
# 2     008359041  25476751  2010-04-21         O  BETJ
# 3     008359041  25066396  2010-04-23         O  SRN4
# 4     008359041  25481334  2010-05-14         O  SRRO
# ...         ...       ...         ...       ...   ...
# 3368  128082786  31642742  2024-01-17         O   G1P
# 3369  128082786  31642742  2024-01-17         O   G1P
# 3370  128082786  31710528  2024-01-30         O   G1P
# 3371  128082786  31710528  2024-01-30         O   G1P
# 3372  128082786  31710528  2024-01-30         O   G1P
#
#                                 DESCR TX_TYPE  VER_NO  SEQ_NO  TYPE_ORDER  \
# 0                  Neurológiai szakr.     ANM       1       0           1
# 1                           UH /hasi/     ANM       1       0           1
# 2            Betöltéshez járó osztály     ANM       1       0           1
# 3                  Neurológiai szakr.     ANM       1       0           1
# 4                 Ált.reumatol.szakr.     ANM       1       0           1
# ...                               ...     ...     ...     ...         ...
# 3368  Gyermekpszichiátriai Ambulancia     DEC       1       0           3
# 3369  Gyermekpszichiátriai Ambulancia     STA       1       0           7
# 3370  Gyermekpszichiátriai Ambulancia     ANM       1       0           1
# 3371  Gyermekpszichiátriai Ambulancia     EPD       3       0           4
# 3372  Gyermekpszichiátriai Ambulancia     STA       1       0           7
#
#            TYPE                                              VALUE  \
# 0     Anamnézis  Jo-i hydronephrosis miatt veseeltáv., ulcusbet...
# 1     Anamnézis  Rad.lelet
# KOPONYA CT VIZSGÁLAT
# A vizsgálat sor...
# 2     Anamnézis  Rad.lelet
# KOPONYA CT VIZSGÁLAT
# A vizsgálat sor...
# 3     Anamnézis  Kontroll vizsgálat:
# 10.04.21 Radiológia: , 2 ...
# 4     Anamnézis  Rad.lelet
# 2 ir. lumbalis gerinc felvétel:
# ----...
# ...         ...                                                ...
# 3368   Dekurzus  A gyermekpszichológiai konzílium eredménye ala...
# 3369    Státusz  Tudata éber, integrált, minden tekintetben ori...
# 3370  Anamnézis  A 15 éves, 9. osztályos serdülő édesanyjával é...
# 3371  Epikrízis  A 15 éves serdülő édesanyja kíséretében érkezi...
# 3372    Státusz  Tudata éber, integrált, minden tekintetben ori...
#
#                                                    TEXT  \
# 0     ANAMNÉZIS:
# Jo-i hydronephrosis miatt veseeltáv...
# 1     ANAMNÉZIS:
# Rad.lelet
# 	KOPONYA CT VIZSGÁLAT
# 	A ...
# 2     ANAMNÉZIS:
# Rad.lelet
# 	KOPONYA CT VIZSGÁLAT
# 	A ...
# 3     ANAMNÉZIS:
# Kontroll vizsgálat:
# 	10.04.21 Radi...
# 4     ANAMNÉZIS:
# Rad.lelet
# 	2 ir. lumbalis gerinc fe...
# ...                                                 ...
# 3368  DEKURZUS:
# A gyermekpszichológiai konzílium ere...
# 3369  STÁTUSZ:
# Tudata éber, integrált, minden tekint...
# 3370  ANAMNÉZIS:
# A 15 éves, 9. osztályos serdülő éde...
# 3371  EPIKRÍZIS:
# A 15 éves serdülő édesanyja kíséret...
# 3372  STÁTUSZ:
# Tudata éber, integrált, minden tekint...
#
#                                                   TEXT2  \
# 0     ANAMNÉZIS (2010-03-30):
# Jo-i hydronephrosis mi...
# 1     ANAMNÉZIS (2010-04-21):
# Rad.lelet
# 	KOPONYA CT ...
# 2     ANAMNÉZIS (2010-04-21):
# Rad.lelet
# 	KOPONYA CT ...
# 3     ANAMNÉZIS (2010-04-23):
# Kontroll vizsgálat:
# 	...
# 4     ANAMNÉZIS (2010-05-14):
# Rad.lelet
# 	2 ir. lumba...
# ...                                                 ...
# 3368  DEKURZUS (2024-01-17):
# A gyermekpszichológiai ...
# 3369  STÁTUSZ (2024-01-17):
# Tudata éber, integrált, ...
# 3370  ANAMNÉZIS (2024-01-30):
# A 15 éves, 9. osztályo...
# 3371  EPIKRÍZIS (2024-01-30):
# A 15 éves serdülő édes...
# 3372  STÁTUSZ (2024-01-30):
# Tudata éber, integrált, ...
#
#                                              FINAL_TEXT
# 0     ANAMNÉZIS:\nJo-i hydronephrosis miatt veseeltá...
# 1     ANAMNÉZIS:\nRad.lelet\n\tKOPONYA CT VIZSGÁLAT\...
# 2     ANAMNÉZIS:\nRad.lelet\n\tKOPONYA CT VIZSGÁLAT\...
# 3     ANAMNÉZIS:\nKontroll vizsgálat: \n\t10.04.21 R...
# 4     ANAMNÉZIS:\nRad.lelet\n\t2 ir. lumbalis gerinc...
# ...                                                 ...
# 3368  DEKURZUS (2024-01-17):\nA gyermekpszichológiai...
# 3369  STÁTUSZ (2024-01-17):\nTudata éber, integrált,...
# 3370  ANAMNÉZIS:\nA 15 éves, 9. osztályos serdülő éd...
# 3371  EPIKRÍZIS (2024-01-30):\nA 15 éves serdülő éde...
# 3372  STÁTUSZ (2024-01-30):\nTudata éber, integrált,...
#
# [3373 rows x 15 columns]

# %%
df_melt[df_melt['NPI'] == "013763925"]
# Out:
#            NPI   CASE_NO  ADMIT_DATE CASE_TYPE  DEPT  \
# 162  013763925  10281581  2011-08-02         O   KAE
# 163  013763925  10688155  2011-11-17         O   KAE
# 164  013763925  11103317  2012-03-07         O   KAE
# 165  013763925  12786757  2013-05-23         O  KAEE
# 166  013763925  12936705  2013-07-01         O  KAEE
# ..         ...       ...         ...       ...   ...
# 233  013763925  16046089  2015-09-21         O   B1N
# 234  013763925  16052715  2015-09-22         O   B1N
# 235  013763925  16377070  2015-11-19         I  SVSZ
# 236  013763925  16377070  2015-11-19         I  SVSZ
# 237  013763925  16682903  2016-02-26         O  BRÁ5
#
#                                   DESCR TX_TYPE  VER_NO  SEQ_NO  TYPE_ORDER  \
# 162     CVC Kardiológai Ambulancia - PM     EPD       2       0           4
# 163     CVC Kardiológai Ambulancia - PM     EPD       4       0           4
# 164     CVC Kardiológai Ambulancia - PM     EPD       3       0           4
# 165  CVC 2. Kardiológiai-EKG Ambulancia     EPD       4       0           4
# 166  CVC 2. Kardiológiai-EKG Ambulancia     EPD       1       0           4
# ..                                  ...     ...     ...     ...         ...
# 233         Nephrológiai Szakambulancia     EPD       1       0           4
# 234         Nephrológiai Szakambulancia     DEC       2       0           3
# 235               Szívsebészeti osztály     DEC      19       0           3
# 236               Szívsebészeti osztály     EPD      12       0           4
# 237        Bőrgyógyászat Szakambulancia     ANM       1       0           1
#
#           TYPE                                              VALUE  \
# 162  Epikrízis  A beteg kontrollvizsgálaton megjelent. NYHA II...
# 163  Epikrízis  A beteg kontrollvizsgálaton megjelent. NYHA II...
# 164  Epikrízis  A beteg kontrollvizsgálaton megjelent. NYHA II...
# 165  Epikrízis  A beteg kontrollon megjelent. NYHA I-II. Panas...
# 166  Epikrízis          Inspra receptrtel ellátva.
# Tisztelettel,
# ..         ...                                                ...
# 233  Epikrízis  A betegnél mai napon 12 h-s CVVHD kezelést fol...
# 234   Dekurzus  NEPHROLOGIA -- DIALÍZIS
# S: a beteg a Tx ITO-n ...
# 235   Dekurzus  Dekurzus:
# 2015.12.11.
# Mai napon a betegnek 1db...
# 236  Epikrízis  Betegünk anamnéziséből kiemelendő konzervatív ...
# 237  Anamnézis  SZívtranszplantáció előtti szűrővizsgálatát ké...
#
#                                                   TEXT  \
# 162  EPIKRÍZIS:
# A beteg kontrollvizsgálaton megjele...
# 163  EPIKRÍZIS:
# A beteg kontrollvizsgálaton megjele...
# 164  EPIKRÍZIS:
# A beteg kontrollvizsgálaton megjele...
# 165  EPIKRÍZIS:
# A beteg kontrollon megjelent. NYHA ...
# 166  EPIKRÍZIS:
# Inspra receptrtel ellátva.
# 	Tiszte...
# ..                                                 ...
# 233  EPIKRÍZIS:
# A betegnél mai napon 12 h-s CVVHD k...
# 234  DEKURZUS:
# NEPHROLOGIA -- DIALÍZIS
# 	S: a beteg ...
# 235  DEKURZUS:
# Dekurzus:
# 	2015.12.11.
# 	Mai napon a ...
# 236  EPIKRÍZIS:
# Betegünk anamnéziséből kiemelendő k...
# 237  ANAMNÉZIS:
# SZívtranszplantáció előtti szűrőviz...
#
#                                                  TEXT2  \
# 162  EPIKRÍZIS (2011-08-02):
# A beteg kontrollvizsgá...
# 163  EPIKRÍZIS (2011-11-17):
# A beteg kontrollvizsgá...
# 164  EPIKRÍZIS (2012-03-07):
# A beteg kontrollvizsgá...
# 165  EPIKRÍZIS (2013-05-23):
# A beteg kontrollon meg...
# 166  EPIKRÍZIS (2013-07-01):
# Inspra receptrtel ellá...
# ..                                                 ...
# 233  EPIKRÍZIS (2015-09-21):
# A betegnél mai napon 1...
# 234  DEKURZUS (2015-09-22):
# NEPHROLOGIA -- DIALÍZIS...
# 235  DEKURZUS (2015-11-19):
# Dekurzus:
# 	2015.12.11.
# ...
# 236  EPIKRÍZIS (2015-11-19):
# Betegünk anamnéziséből...
# 237  ANAMNÉZIS (2016-02-26):
# SZívtranszplantáció el...
#
#                                             FINAL_TEXT
# 162  EPIKRÍZIS (2011-08-02):\nA beteg kontrollvizsg...
# 163  EPIKRÍZIS (2011-11-17):\nA beteg kontrollvizsg...
# 164  EPIKRÍZIS (2012-03-07):\nA beteg kontrollvizsg...
# 165  EPIKRÍZIS (2013-05-23):\nA beteg kontrollon me...
# 166  EPIKRÍZIS (2013-07-01):\nInspra receptrtel ell...
# ..                                                 ...
# 233  EPIKRÍZIS (2015-09-21):\nA betegnél mai napon ...
# 234  DEKURZUS (2015-09-22):\nNEPHROLOGIA -- DIALÍZI...
# 235  DEKURZUS (2015-11-19):\nDekurzus:\n\t2015.12.1...
# 236  EPIKRÍZIS (2015-11-19):\nBetegünk anamnézisébő...
# 237  ANAMNÉZIS:\nSZívtranszplantáció előtti szűrővi...
#
# [76 rows x 15 columns]

# %%
# Merge ANM and EPD text only
df_merged_filtered = df_melt[df_melt['TX_TYPE'].isin(('ANM', 'EPD'))].groupby(['NPI','ADMIT_DATE','CASE_NO','CASE_TYPE','DEPT','DESCR'])[['FINAL_TEXT']].agg("\n\n".join).reset_index(level=-1)
df_merged_filtered
# Out:
#                                                                             DESCR  \
# NPI       ADMIT_DATE CASE_NO  CASE_TYPE DEPT
# 008359041 2010-03-30 25054122 O         SRN4                   Neurológiai szakr.
#           2010-04-21 25369254 O         KEUH                            UH /hasi/
#                      25476751 O         BETJ             Betöltéshez járó osztály
#           2010-04-23 25066396 O         SRN4                   Neurológiai szakr.
#           2010-05-14 25481334 O         SRRO                  Ált.reumatol.szakr.
# ...                                                                           ...
# 128082786 2023-01-19 29978989 O         FGA              Általános F.O.G. osztály
#           2023-02-10 29921771 O         FGT                         Otoneurológia
#           2024-01-09 31593207 I         G14   Belgyógyászat-Gastroenterológiai O.
#           2024-01-17 31642742 O         G1P       Gyermekpszichiátriai Ambulancia
#           2024-01-30 31710528 O         G1P       Gyermekpszichiátriai Ambulancia
#
#                                                                                      FINAL_TEXT
# NPI       ADMIT_DATE CASE_NO  CASE_TYPE DEPT
# 008359041 2010-03-30 25054122 O         SRN4  ANAMNÉZIS:\nJo-i hydronephrosis miatt veseeltá...
#           2010-04-21 25369254 O         KEUH  ANAMNÉZIS:\nRad.lelet\n\tKOPONYA CT VIZSGÁLAT\...
#                      25476751 O         BETJ  ANAMNÉZIS:\nRad.lelet\n\tKOPONYA CT VIZSGÁLAT\...
#           2010-04-23 25066396 O         SRN4  ANAMNÉZIS:\nKontroll vizsgálat: \n\t10.04.21 R...
#           2010-05-14 25481334 O         SRRO  ANAMNÉZIS:\nRad.lelet\n\t2 ir. lumbalis gerinc...
# ...                                                                                         ...
# 128082786 2023-01-19 29978989 O         FGA   ANAMNÉZIS:\n2023.01.19. Augusztus vége óta nem...
#           2023-02-10 29921771 O         FGT   ANAMNÉZIS:\n2022. augusztusban orrdugulásos pa...
#           2024-01-09 31593207 I         G14   ANAMNÉZIS:\nNegatív perinatalis anamnezis. III...
#           2024-01-17 31642742 O         G1P   ANAMNÉZIS:\nAnamnéziséből kiemelendő: A 15 éve...
#           2024-01-30 31710528 O         G1P   ANAMNÉZIS:\nA 15 éves, 9. osztályos serdülő éd...
#
# [1526 rows x 2 columns]

# %%
# Write each patient document (per case number) to txt files
ext = 'txt'
dir = 'patient'
filtered_subdir = 'src/filtered'

for i in df_merged_filtered.index:
  # Get metadata
  npi = i[0]
  admit_date = i[1]
  case_no = i[2]
  case_type = i[3]
  dept = i[4]

  # Set patient folder as NPI
  patient_dir = f'{(i[0])}'
  output_dir = os.path.join(data_path, dir, patient_dir, filtered_subdir)

  # Make output directory if does not exist
  if not os.path.exists(output_dir):
      os.makedirs(output_dir)

  # Set output filename as NPI+ADMIT_DATE+CASE_NO+CASE_TYPE+DEPT
  fname = f'{npi}_{admit_date}_{case_no}_{case_type}_{dept}_filtered.{ext}'
  output_file = os.path.join(output_dir, fname)

  # Get content for output file
  department = df_merged_filtered.loc[i, 'DESCR']
  text = df_merged_filtered.loc[i, 'FINAL_TEXT']

  # Create header
  # header = f'ZÁRÓJELENTÉS\nPáciens: {npi} | Rögzítési dátum: {admit_date} | Dokumentum: {case_no} | Osztály: {department} ({dept})\n\n'

  # Write output file
  print(f'\rWriting case {case_no} for patient {npi}\t\t', end='')
  with open(output_file, 'w') as f:
    # f.write(header)
    f.write(text)

print('\rAll files complete')
# Out:
# All files complete

# %%
df_merged_filtered.reset_index().groupby("NPI")[['CASE_NO']].count()
# Out:
#            CASE_NO
# NPI
# 008359041       50
# 011547185       31
# 013763925       39
# 014317617       50
# 017366126       82
# 019116202       24
# 019131629       20
# 021009268       51
# 021508668       45
# 022231615       62
# 022387169       82
# 022461890       48
# 023283291       26
# 023774843        7
# 023799222       59
# 024264958       13
# 027883336       49
# 028520047      102
# 029552184       44
# 042344593       37
# 058754654        5
# 062458289        9
# 064740335       13
# 069692954       46
# 071261537      117
# 074177352       18
# 078391338       42
# 094385775       48
# 094754894       75
# 102195156        6
# 104787935       81
# 105368364      135
# 128082786       10

# %%
print(output_file)
# Out:
# /content/drive/MyDrive/Projektek/Semmelweis PoC/202401_Semmelweis - GenAI anamnézis - PoC (425)/10_Kapott_anyagok/kapott_anyagok_ 2024_02_06/patient/128082786/src/filtered/128082786_2024-01-30_31710528_O_G1P_filtered.txt
